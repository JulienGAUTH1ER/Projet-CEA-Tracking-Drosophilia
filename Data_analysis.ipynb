# %%
# %pip install ipywidgets
# %pip install IPython
# %pip install json
# %pip install pathlib
# %pip install numpy
# %pip install sys
# %pip install pandas
# %pip install matplotlib
# %pip install seaborn
# %matplotlib inline
# Out:
# Requirement already satisfied: ipywidgets in c:\users\julie\appdata\local\programs\python\python310\lib\site-packages (8.1.8)
# Requirement already satisfied: comm>=0.1.3 in c:\users\julie\appdata\roaming\python\python310\site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\julie\appdata\roaming\python\python310\site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\julie\appdata\roaming\python\python310\site-packages (from ipywidgets) (8.37.0)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\julie\appdata\local\programs\python\python310\lib\site-packages (from ipywidgets) (3.0.16)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\julie\appdata\local\programs\python\python310\lib\site-packages (from ipywidgets) (4.0.15)
# Requirement already satisfied: exceptiongroup in c:\users\julie\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets) (1.3.1)
# Requirement already satisfied: matplotlib-inline in c:\users\julie\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets) (0.2.1)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\julie\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets) (2.19.2)
# Requirement already satisfied: typing_extensions>=4.6 in c:\users\julie\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets) (4.15.0)
# Requirement already satisfied: decorator in c:\users\julie\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\julie\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.52)
# Requirement already satisfied: colorama in c:\users\julie\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: jedi>=0.16 in c:\users\julie\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: stack_data in c:\users\julie\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\julie\appdata\roaming\python\python310\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.5)
# Requirement already satisfied: wcwidth in c:\users\julie\appdata\roaming\python\python310\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.14)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\julie\appdata\roaming\python\python310\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (3.0.1)
# Requirement already satisfied: executing>=1.2.0 in c:\users\julie\appdata\roaming\python\python310\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: pure-eval in c:\users\julie\appdata\roaming\python\python310\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: IPython in c:\users\julie\appdata\roaming\python\python310\site-packages (8.37.0)
# Requirement already satisfied: exceptiongroup in c:\users\julie\appdata\roaming\python\python310\site-packages (from IPython) (1.3.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\julie\appdata\roaming\python\python310\site-packages (from IPython) (3.0.52)
# Requirement already satisfied: colorama in c:\users\julie\appdata\roaming\python\python310\site-packages (from IPython) (0.4.6)
# Requirement already satisfied: decorator in c:\users\julie\appdata\roaming\python\python310\site-packages (from IPython) (5.2.1)
# Requirement already satisfied: matplotlib-inline in c:\users\julie\appdata\roaming\python\python310\site-packages (from IPython) (0.2.1)
# Requirement already satisfied: typing_extensions>=4.6 in c:\users\julie\appdata\roaming\python\python310\site-packages (from IPython) (4.15.0)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\julie\appdata\roaming\python\python310\site-packages (from IPython) (5.14.3)
# Requirement already satisfied: stack_data in c:\users\julie\appdata\roaming\python\python310\site-packages (from IPython) (0.6.3)
# Requirement already satisfied: jedi>=0.16 in c:\users\julie\appdata\roaming\python\python310\site-packages (from IPython) (0.19.2)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\julie\appdata\roaming\python\python310\site-packages (from IPython) (2.19.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\julie\appdata\roaming\python\python310\site-packages (from jedi>=0.16->IPython) (0.8.5)
# Requirement already satisfied: wcwidth in c:\users\julie\appdata\roaming\python\python310\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->IPython) (0.2.14)
# Requirement already satisfied: executing>=1.2.0 in c:\users\julie\appdata\roaming\python\python310\site-packages (from stack_data->IPython) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\julie\appdata\roaming\python\python310\site-packages (from stack_data->IPython) (3.0.1)
# Requirement already satisfied: pure-eval in c:\users\julie\appdata\roaming\python\python310\site-packages (from stack_data->IPython) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement json (from versions: none)
# ERROR: No matching distribution found for json
#
# [notice] A new release of pip is available: 23.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: pathlib in c:\users\julie\appdata\local\programs\python\python310\lib\site-packages (1.0.1)
# [notice] A new release of pip is available: 23.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: numpy in c:\users\julie\appdata\local\programs\python\python310\lib\site-packages (2.2.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement sys (from versions: none)
# ERROR: No matching distribution found for sys
#
# [notice] A new release of pip is available: 23.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: pandas in c:\users\julie\appdata\local\programs\python\python310\lib\site-packages (2.3.3)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\julie\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\julie\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\julie\appdata\roaming\python\python310\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\julie\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2.2.6)
# Requirement already satisfied: six>=1.5 in c:\users\julie\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 23.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in c:\users\julie\appdata\local\programs\python\python310\lib\site-packages (3.10.8)
# Requirement already satisfied: cycler>=0.10 in c:\users\julie\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: pillow>=8 in c:\users\julie\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (12.1.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\julie\appdata\roaming\python\python310\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\julie\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\julie\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\julie\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\julie\appdata\roaming\python\python310\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pyparsing>=3 in c:\users\julie\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (3.3.1)
# Requirement already satisfied: numpy>=1.23 in c:\users\julie\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (2.2.6)
# Requirement already satisfied: six>=1.5 in c:\users\julie\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# [notice] A new release of pip is available: 23.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: seaborn in c:\users\julie\appdata\local\programs\python\python310\lib\site-packages (0.13.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\julie\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: pandas>=1.2 in c:\users\julie\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\julie\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (2.2.6)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\julie\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: pyparsing>=3 in c:\users\julie\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\julie\appdata\roaming\python\python310\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\julie\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\julie\appdata\roaming\python\python310\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: cycler>=0.10 in c:\users\julie\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: pillow>=8 in c:\users\julie\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.1.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\julie\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.61.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\julie\appdata\local\programs\python\python310\lib\site-packages (from pandas>=1.2->seaborn) (2025.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\julie\appdata\local\programs\python\python310\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\julie\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import ipywidgets as widgets
from IPython.display import display, clear_output
import json
from pathlib import Path
from scipy.signal import savgol_filter

import numpy as np
import sys
import cv2
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import seaborn as sns


project_root = Path("..").resolve()
sys.path.append(str(project_root))
from Calibration.Parameters import CHAMBERS_COLORS

# %% [markdown]
# ## Résultats pour une larve individuelle

# %% [markdown]
# <div style="
# background-color:#000000;
# padding:12px;
# border-radius:6px;
# border:1px solid #000000;
# ">
#
# ###  Paramètres à définir
#
# Veuillez entrer le numéro d'expérience, ainsi que le numéro du labyrinthe d'étude

# %%
lab_letters = ["A","B","C","D","E","F","G","H"]
lab_position = ["top","bottom"]

project_root = Path("..").resolve()
data_folder = project_root / "Data"

experiment_folders = sorted([f.name for f in data_folder.iterdir() if f.is_dir()])

exp_dropdown = widgets.Dropdown(
    options=experiment_folders,
    description='Expérience:',
    style={'description_width':'initial'}
)

letter_dropdown = widgets.Dropdown(
    options=lab_letters,
    value=lab_letters[0],
    description='Labyrinthe:',
    style={'description_width':'initial'}
)

position_dropdown = widgets.Dropdown(
    options=lab_position,
    value=lab_position[0],
    description='Partie:',
    style={'description_width':'initial'}
)

validate_button = widgets.Button(description='Valider', button_style='success')
output = widgets.Output()


def on_validate_clicked(b):

    with output:

        clear_output()

        Experiment = exp_dropdown.value
        Double_Maze = letter_dropdown.value
        Maze = position_dropdown.value

        Mazes_name = f"Maze_{Double_Maze}"
        Maze_name = f"Maze_{Double_Maze}_{Maze}"

        print(f"Expérience choisie: {Experiment}")
        print(f"Labyrinthe choisi: {Maze_name}")

        tracking_file = data_folder / Experiment / "Video" / "Mazes" / Mazes_name / f"{Maze_name}_tracking.json"

        print("Chemin :", tracking_file)

        if not tracking_file.exists():
            print("Attention, fichier introuvable")
            return

        # Charger le tracking
        with open(tracking_file) as f:
            data = json.load(f)

        fps = data["fps"]

        df = pd.DataFrame(data["tracking"])

        df["x"] = df["position"].apply(lambda p: p["x"] if p else None)
        df["y"] = df["position"].apply(lambda p: p["y"] if p else None)

        df = df.drop(columns="position")

        print("Tracking chargé avec succès !")


validate_button.on_click(on_validate_clicked)
ui = widgets.VBox([
    exp_dropdown,
    widgets.HBox([letter_dropdown, position_dropdown, validate_button]),
    output
])
display(ui)
# Out:
# VBox(children=(Dropdown(description='Expérience:', options=('Experiment_1_11032026', 'Experiment_1_13032026', …

# %%
Experiment = exp_dropdown.value
Double_Maze = letter_dropdown.value
Maze = position_dropdown.value

Mazes_name = f"Maze_{Double_Maze}"
Maze_name = f"Maze_{Double_Maze}_{Maze}"

tracking_video = (
    project_root
    / "Data"
    / Experiment
    / "Video"
    / "Mazes"
    / Mazes_name
    / f"{Maze_name}.mp4"
)

cap = cv2.VideoCapture(str(tracking_video))

if not cap.isOpened():
    raise ValueError(f"La vidéo n'a pas pu être ouverte : {tracking_video}")

ret, frame = cap.read()

if not ret:
    raise ValueError("Impossible de lire la première frame")

video_height, video_width = frame.shape[:2]

cap.release()

print(f"Taille vidéo : {video_width} x {video_height}")
# Out:
# Taille vidéo : 888 x 928

# %%
mask_path_top = project_root / "Calibration" / "Maze_pictures" / "Maze_mask_top_painted.png"
mask_path_bottom = project_root / "Calibration" / "Maze_pictures" / "Maze_mask_bottom_painted.png"

mask_top = cv2.imread(str(mask_path_top))
mask_bottom = cv2.imread(str(mask_path_bottom))
mask_top = cv2.cvtColor(mask_top, cv2.COLOR_BGR2RGB)
mask_bottom = cv2.cvtColor(mask_bottom, cv2.COLOR_BGR2RGB)


mask_top = cv2.resize(
    mask_top,
    (video_width, video_height),
    interpolation=cv2.INTER_NEAREST
)

mask_bottom = cv2.resize(
    mask_bottom,
    (video_width, video_height),
    interpolation=cv2.INTER_NEAREST
)

if Maze == "top":
    mask_resized = mask_top
else:
    mask_resized = mask_bottom

# %%
tracking_file = project_root / "Data" / Experiment / "Video" / "Mazes" / Mazes_name / f"{Maze_name}_tracking.json"

with open(tracking_file) as f:
    data = json.load(f)

fps = data["fps"]
tracking = data["tracking"]

df = pd.DataFrame(tracking)
df["x"] = df["position"].apply(lambda p: p["x"] if p else None)
df["y"] = df["position"].apply(lambda p: p["y"] if p else None)
df = df.drop(columns="position")

print("Tracking chargé :", df.shape, "frames")
# Out:
# Tracking chargé : (18571, 7) frames

# %% [markdown]
# ## Zones de visites

# %%
COLOR_MAP = { "Red": (255,0,0), "Green": (0,255,0), "Blue": (0,0,255), "White": (255,255,255) }

CHAMBERS_RGB = { chamber: COLOR_MAP[color] for chamber, color in CHAMBERS_COLORS.items() }

chamber_index = { "Chambre_1": 1, "Chambre_3": 3, "Chambre_2": 2, "Decision_zone": 4 }

chamber_map = np.zeros(mask_resized.shape[:2], dtype=int)

for chamber, rgb in CHAMBERS_RGB.items():
    mask_pixels = np.all(mask_resized == rgb, axis=2)
    chamber_map[mask_pixels] = chamber_index[chamber]
plt.figure(figsize=(8, 8))
plt.imshow(chamber_map)
plt.title("Trajectoire de la larve")
plt.plot(df["x"], df["y"], color='black', linewidth=1, alpha=0.7)
plt.scatter(df["x"], df["y"], color='yellow', s=5, alpha=0.5)
plt.gca().invert_yaxis()
plt.xlabel("X (pixels)")
plt.ylabel("Y (pixels)")
plt.show()

# %%
df["x_int"] = df["x"].astype("Int64")
df["y_int"] = df["y"].astype("Int64")

height, width = chamber_map.shape

df["chamber_id"] = [
    chamber_map[y, x]
    if pd.notna(x) and pd.notna(y) and 0 <= x < width and 0 <= y < height
    else 0
    for x, y in zip(df["x_int"], df["y_int"])
]
inverse_map = {v:k for k,v in chamber_index.items()}
inverse_map[0] = "Outside"

df["chamber"] = df["chamber_id"].map(inverse_map)

# %%
colors = {
    0: "lightgray",# Outside
    1: "blue",# Chambre_1
    2: "green",# Chambre_2
    3: "red",# Chambre_3         
    4: "white"# Decision_zone                     
}

cmap = mcolors.ListedColormap([colors[i] for i in sorted(colors.keys())])
bounds = np.array(sorted(colors.keys()) + [max(colors.keys())+1])
norm = mcolors.BoundaryNorm(bounds, cmap.N)

plt.figure(figsize=(14, 2))
plt.imshow(
    df["chamber_id"].values.reshape(1, -1),
    aspect="auto",
    cmap=cmap,
    norm=norm
)

plt.yticks([])

cbar = plt.colorbar(ticks=list(colors.keys()), orientation="vertical")
cbar.ax.set_yticklabels([inverse_map[i] for i in sorted(colors.keys())])
cbar.set_label("Chambre")

plt.xlabel("Frames")
plt.title("Timeline comportementale")
plt.show()

# %%
time_spent_sec = df.groupby("chamber").size() / fps

colors = {
    0: "lightgray",  # Outside
    1: "blue",       # Chambre_1
    2: "green",      # Chambre_2
    3: "red",        # Chambre_3
    4: "white"       # Decision_zone
}
name_to_key = {
    "Outside": 0,
    "Chambre_1": 1,
    "Chambre_2": 2,
    "Chambre_3": 3,
    "Decision_zone": 4
}

sorted_times = time_spent_sec.sort_values()

bar_colors = [colors[name_to_key[ch]] for ch in sorted_times.index]
sns.set_style("whitegrid")
plt.figure(figsize=(8,4))
bars = plt.barh(sorted_times.index, sorted_times.values, color=bar_colors, edgecolor='black', alpha=0.85)

for bar in bars:
    width = bar.get_width()
    plt.text(width + 0.2, bar.get_y() + bar.get_height()/2,
             f"{width:.1f}s", va='center', fontsize=10)

plt.xlabel("Temps (secondes)")
plt.title("Temps passé dans chaque chambre", fontsize=14)
plt.xlim(0, max(sorted_times.values)*1.2)
plt.tight_layout()
plt.show()



# Reprendre le même ordre que le barplot
pie_labels = sorted_times.index
pie_values = sorted_times.values

# Couleurs cohérentes
pie_colors = [colors[name_to_key[ch]] for ch in pie_labels]

wedges, texts, autotexts = plt.pie(
    pie_values,
    labels=pie_labels,
    colors=pie_colors,
    autopct=lambda p: f'{p:.1f}%\n({p/100*sum(pie_values):.1f}s)',
    startangle=90,
    pctdistance=0.75,
    wedgeprops={'edgecolor': 'white', 'linewidth': 2}
)

# Effet donut
centre_circle = plt.Circle((0,0), 0.55, fc='white')
plt.gca().add_artist(centre_circle)

plt.title("Temps passé dans chaque chambre", fontsize=14)
plt.tight_layout()
plt.show()

# %%
df["speed_px_per_sec"] = pd.to_numeric(df["speed_px_per_sec"], errors="coerce")
df["speed_clean"] = df["speed_px_per_sec"].clip(upper=200)
df["speed_interp"] = df["speed_clean"].interpolate()
df["speed_sg"] = savgol_filter(
    df["speed_interp"],
    window_length=201,   # impair
    polyorder=3)

df["chamber_change"] = df["chamber"] != df["chamber"].shift(1)
change_times = df.loc[df["chamber_change"], "time_sec"]
change_chambers = df.loc[df["chamber_change"], "chamber"]

plt.figure(figsize=(12,5))

plt.plot(df["time_sec"], df["speed_clean"], color='gray', alpha=0.8, label="Brut")
plt.plot(df["time_sec"], df["speed_sg"], color='blue', linewidth=2, label="Savitzky-Golay")

chamber_colors = {
    "Outside": "lightgray",
    "Chambre_1": "blue",
    "Chambre_2": "green",
    "Chambre_3": "red",
    "Decision_zone": "white"
}

for i in range(len(df)-1):
    plt.axvspan(
        df["time_sec"].iloc[i],
        df["time_sec"].iloc[i+1],
        color=chamber_colors.get(df["chamber"].iloc[i], "gray"),
        alpha=0.01
    )

# Labels
plt.xlabel("Temps (s)")
plt.ylabel("Vitesse (px/s)")
plt.title("Vitesse de la larve avec transitions de chambres")

plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\julie\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
